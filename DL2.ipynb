# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words = 10000)

# %%
X_train= pad_sequences(X_train, maxlen=200)
X_test = pad_sequences(X_test, maxlen=200)

# %%
model = Sequential()
model.add(Embedding(input_dim =10000, output_dim=32, input_length=200))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs= 5,batch_size= 32, validation_split=0.1)
# Out:
# Epoch 1/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7969 - loss: 0.4123 - val_accuracy: 0.8508 - val_loss: 0.3384
# Epoch 2/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9520 - loss: 0.1376 - val_accuracy: 0.8576 - val_loss: 0.3655
# Epoch 3/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9945 - loss: 0.0243 - val_accuracy: 0.8560 - val_loss: 0.4605
# Epoch 4/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.8448 - val_loss: 0.5467
# Epoch 5/5
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 1.0000 - loss: 9.0731e-04 - val_accuracy: 0.8504 - val_loss: 0.5820

# %%
loss, acc= model.evaluate(X_test, y_test)
print("test loss", loss)
print("test accuracy",acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8509 - loss: 0.5805
# test loss 0.5804756879806519
# test accuracy 0.8508800268173218

# %%
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()
